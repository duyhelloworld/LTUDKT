# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Đọc dữ liệu từ file Excel
excel_file = './DuLieuEXCEL.xlsx'
df_sinh_vien = pd.read_excel(excel_file, sheet_name='Sinh Vien')
df_diem_mon_1 = pd.read_excel(excel_file, sheet_name='Diem Mon 1')
df_diem_mon_2 = pd.read_excel(excel_file, sheet_name='Diem Mon 2')
df_diem_mon_3 = pd.read_excel(excel_file, sheet_name='Diem Mon 3')

# %%
# Hiển thị dữ liệu của các DataFrame
print("DataFrame Sinh Vien:")
print(df_sinh_vien)
# Out:
# DataFrame Sinh Vien:
#     STT  Ma Sinh Vien                Ho Ten  Ngay Sinh Gioi Tinh Lop Quan Ly
# 0     1        189456             Le Van Do 2003-05-11       Nam       66PM1
# 1     2        198436         Nguyen Van An 2003-06-17       Nam       66PM5
# 2     3        208472  Tran Thi Khanh Huyen 2003-01-21        Nữ      66MHT1
# 3     4        208473          Tran Van Tho 2003-01-22       Nam      66MHT2
# 4     5        208474     Nguyen Hoang Thuy 2003-01-23        Nữ      66MHT3
# 5     6        208475            Vo Van Nam 2003-01-24       Nam      66MHT4
# 6     7        208476     Tran Thi Kim Dung 2003-01-25        Nữ      66MHT5
# 7     8        208477         Pho Thuy Linh 2003-01-26        Nữ      66MHT6
# 8     9        208478        Tran Thi Quynh 2003-01-27        Nữ       66PM6
# 9    10        208479  Nguyen Le Phuong Anh 2003-01-28        Nữ       66PM1
# 10   11        208480  Nguyen Le Anh Phuong 2003-01-29        Nữ       66PM4
# ...

# %%
print("\nDataFrame Diem Mon 1:")
print(df_diem_mon_1)
# Out:
# DataFrame Diem Mon 1:
#     STT  Ma Sinh Vien                Ho Ten  Diem Qua Trinh  Diem Cuoi Ky
# 0     1        189456             Le Van Do             7.0           4.0
# 1     2        198436         Nguyen Van An             6.0           4.5
# 2     3        208472  Tran Thi Khanh Huyen             8.5           6.0
# 3     4        208473          Tran Van Tho             8.6           6.8
# 4     5        208474     Nguyen Hoang Thuy             8.5           5.2
# 5     6        208475            Vo Van Nam            10.0           8.8
# 6     7        208476     Tran Thi Kim Dung             7.0           5.5
# 7     8        208477         Pho Thuy Linh             6.5           5.5
# 8     9        208478        Tran Thi Quynh             5.6           6.8
# 9    10        208479  Nguyen Le Phuong Anh             9.0           7.0
# 10   11        208480  Nguyen Le Anh Phuong             7.8           7.6
# ...

# %%
print("\nDataFrame Diem Mon 2:")
print(df_diem_mon_2)
# Out:
# DataFrame Diem Mon 2:
#     STT  Ma Sinh Vien                Ho Ten  Diem Qua Trinh  Diem Cuoi Ky
# 0     1        189456             Le Van Do             7.0           4.0
# 1     2        198436         Nguyen Van An             6.0           4.5
# 2     3        208472  Tran Thi Khanh Huyen             8.5           6.0
# 3     4        208473          Tran Van Tho             8.6           6.8
# 4     5        208474     Nguyen Hoang Thuy             9.4           7.8
# 5     6        208475            Vo Van Nam            10.0           9.0
# 6     7        208476     Tran Thi Kim Dung             7.0           5.5
# 7     8        208477         Pho Thuy Linh             5.4           5.5
# 8     9        208478        Tran Thi Quynh             5.6           6.8
# 9    10        208479  Nguyen Le Phuong Anh             4.0           7.0
# 10   11        208480  Nguyen Le Anh Phuong             7.8           7.6
# ...

# %%
print("\nDataFrame Diem Mon 3:")
print(df_diem_mon_3)
# Out:
# DataFrame Diem Mon 3:
#     STT  Ma Sinh Vien                Ho Ten  Diem Qua Trinh  Diem Cuoi Ky
# 0     1        189456             Le Van Do             7.0           4.0
# 1     2        198436         Nguyen Van An             6.0           4.5
# 2     3        208472  Tran Thi Khanh Huyen             8.5           6.0
# 3     4        208473          Tran Van Tho             8.6           6.8
# 4     5        208474     Nguyen Hoang Thuy             5.5           5.5
# 5     6        208475            Vo Van Nam            10.0           8.8
# 6     7        208476     Tran Thi Kim Dung             7.0           5.0
# 7     8        208477         Pho Thuy Linh             5.4           5.5
# 8     9        208478        Tran Thi Quynh             4.0           6.0
# 9    10        208479  Nguyen Le Phuong Anh             9.0           7.0
# 10   11        208480  Nguyen Le Anh Phuong             7.8           7.6
# ...

# %% [markdown]
# # C

# %%
#   Tạo DF mới với cột Diem Tong Ket
df_tong_hop = pd.DataFrame(df_sinh_vien["Ma Sinh Vien"])
df_tong_hop["Diem Tong Ket Mon 1"] = df_diem_mon_1["Diem Qua Trinh"] * 0.3 + df_diem_mon_1["Diem Cuoi Ky"] * 0.7
df_tong_hop["Diem Tong Ket Mon 2"] = df_diem_mon_2["Diem Qua Trinh"] * 0.3 + df_diem_mon_2["Diem Cuoi Ky"] * 0.7
df_tong_hop["Diem Tong Ket Mon 3"] = df_diem_mon_3["Diem Qua Trinh"] * 0.3 + df_diem_mon_3["Diem Cuoi Ky"] * 0.7

# %%
# Tự quy định hệ số môn 
he_so_mon_1 = 1
he_so_mon_2 = 1
he_so_mon_3 = 1

# %%
df_tong_hop
# Out:
#     Ma Sinh Vien  Diem Tong Ket Mon 1  Diem Tong Ket Mon 2  \
# 0         189456                 4.90                 4.90
# 1         198436                 4.95                 4.95
# 2         208472                 6.75                 6.75
# 3         208473                 7.34                 7.34
# 4         208474                 6.19                 8.28
# 5         208475                 9.16                 9.30
# 6         208476                 5.95                 5.95
# 7         208477                 5.80                 5.47
# 8         208478                 6.44                 6.44
# 9         208479                 7.60                 6.10
# 10        208480                 7.66                 7.66
# 11        208481                 7.86                 7.86
# 12        208482                 7.93                 5.62
# 13        208483                 7.68                 7.68
# 14        208484                 5.29                 5.29
#
# ...

# %%
# Thêm cột Điểm trung bình
df_tong_hop["Diem Trung Binh"] = round((
    df_tong_hop["Diem Tong Ket Mon 1"] * he_so_mon_1
    + df_tong_hop["Diem Tong Ket Mon 2"] * he_so_mon_2
    + df_tong_hop["Diem Tong Ket Mon 3"] * he_so_mon_3
) / (he_so_mon_1 + he_so_mon_2 + he_so_mon_3), 2)
df_tong_hop
# Out:
#     Ma Sinh Vien  Diem Tong Ket Mon 1  Diem Tong Ket Mon 2  \
# 0         189456                 4.90                 4.90
# 1         198436                 4.95                 4.95
# 2         208472                 6.75                 6.75
# 3         208473                 7.34                 7.34
# 4         208474                 6.19                 8.28
# 5         208475                 9.16                 9.30
# 6         208476                 5.95                 5.95
# 7         208477                 5.80                 5.47
# 8         208478                 6.44                 6.44
# 9         208479                 7.60                 6.10
# 10        208480                 7.66                 7.66
# 11        208481                 7.86                 7.86
# 12        208482                 7.93                 5.62
# 13        208483                 7.68                 7.68
# 14        208484                 5.29                 5.29
#
# ...

# %%
# Hợp nhất dataframe
df_tong_hop = pd.merge(df_sinh_vien, df_tong_hop, on="Ma Sinh Vien")
df_tong_hop
# Out:
#     STT  Ma Sinh Vien                Ho Ten  Ngay Sinh Gioi Tinh Lop Quan Ly  \
# 0     1        189456             Le Van Do 2003-05-11       Nam       66PM1
# 1     2        198436         Nguyen Van An 2003-06-17       Nam       66PM5
# 2     3        208472  Tran Thi Khanh Huyen 2003-01-21        Nữ      66MHT1
# 3     4        208473          Tran Van Tho 2003-01-22       Nam      66MHT2
# 4     5        208474     Nguyen Hoang Thuy 2003-01-23        Nữ      66MHT3
# 5     6        208475            Vo Van Nam 2003-01-24       Nam      66MHT4
# 6     7        208476     Tran Thi Kim Dung 2003-01-25        Nữ      66MHT5
# 7     8        208477         Pho Thuy Linh 2003-01-26        Nữ      66MHT6
# 8     9        208478        Tran Thi Quynh 2003-01-27        Nữ       66PM6
# 9    10        208479  Nguyen Le Phuong Anh 2003-01-28        Nữ       66PM1
# 10   11        208480  Nguyen Le Anh Phuong 2003-01-29        Nữ       66PM4
# ...

# %% [markdown]
# # D

# %%
# Lọc ra những sinh viên không qua môn theo từng môn
df_tong_hop[
    (df_tong_hop["Diem Tong Ket Mon 1"] < 4)
    | (df_tong_hop["Diem Tong Ket Mon 2"] < 4)
    | (df_tong_hop["Diem Tong Ket Mon 3"] < 4)
]
# Out:
# Empty DataFrame
# Columns: [STT, Ma Sinh Vien, Ho Ten, Ngay Sinh, Gioi Tinh, Lop Quan Ly, Diem Tong Ket Mon 1, Diem Tong Ket Mon 2, Diem Tong Ket Mon 3, Diem Trung Binh]
# Index: []

# %% [markdown]
# # E

# %%
# Những sinh viên không trượt môn nào 
df_tong_hop[
    (df_tong_hop["Diem Tong Ket Mon 1"] >= 4)
    & (df_tong_hop["Diem Tong Ket Mon 2"] >= 4)
    & (df_tong_hop["Diem Tong Ket Mon 3"] >= 4)
]
# Out:
#     STT  Ma Sinh Vien                Ho Ten  Ngay Sinh Gioi Tinh Lop Quan Ly  \
# 0     1        189456             Le Van Do 2003-05-11       Nam       66PM1
# 1     2        198436         Nguyen Van An 2003-06-17       Nam       66PM5
# 2     3        208472  Tran Thi Khanh Huyen 2003-01-21        Nữ      66MHT1
# 3     4        208473          Tran Van Tho 2003-01-22       Nam      66MHT2
# 4     5        208474     Nguyen Hoang Thuy 2003-01-23        Nữ      66MHT3
# 5     6        208475            Vo Van Nam 2003-01-24       Nam      66MHT4
# 6     7        208476     Tran Thi Kim Dung 2003-01-25        Nữ      66MHT5
# 7     8        208477         Pho Thuy Linh 2003-01-26        Nữ      66MHT6
# 8     9        208478        Tran Thi Quynh 2003-01-27        Nữ       66PM6
# 9    10        208479  Nguyen Le Phuong Anh 2003-01-28        Nữ       66PM1
# 10   11        208480  Nguyen Le Anh Phuong 2003-01-29        Nữ       66PM4
# ...

# %% [markdown]
# # F

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x="Ma Sinh Vien", y="Diem Trung Binh", data=df_tong_hop)
plt.xlabel("Mã sinh viên")
plt.ylabel("Điểm trung bình")
plt.title("Biểu đồ kết quả học tập của sinh viên")
plt.tight_layout()
plt.yticks(np.arange(0, 11, 1))
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### lí do chọn biểu đồ cột:
# - Thể hiện rõ ràng kết quả học tập theo từng môn học
# - Dễ dàng đánh giá được trung bình điểm các sinh viên
#
# #### lí do chọn 2 cột MaSinhVien và DiemTrungBinh
# - Cột MaSinhVien là định danh duy nhất cho sinh viên (thay vì HoTen có thể trùng và biểu diễn dài)
# - Cột DiemTrungBinh là điểm trung bình các môn của sinh viên

# %% [markdown]
# # G

# %%
excel_writer = pd.ExcelWriter("KetQuaHocTap.xlsx", engine="xlsxwriter")
df_sinh_vien.to_excel(excel_writer, index=False, sheet_name="SinhVien")
df_diem_mon_1.to_excel(excel_writer, index=False, sheet_name="DiemMon1")
df_diem_mon_2.to_excel(excel_writer, index=False, sheet_name="DiemMon2")
df_diem_mon_3.to_excel(excel_writer, index=False, sheet_name="DiemMon3")
df_tong_hop.to_excel(excel_writer, index=False, sheet_name="KetQuaHocTap")
excel_writer.close()
